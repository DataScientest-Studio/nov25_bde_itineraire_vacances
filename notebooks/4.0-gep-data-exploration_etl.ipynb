# %%
from pathlib import Path
import pyarrow.parquet as pq
import pandas as pd

# %% [markdown]
# ### Read csv file

# %%
# read parquet file
path = Path("../src/etl/clean_pois.csv")
df = pd.read_csv(path)
print(df.columns)
print(df.shape)
# Out:
# Index(['id', 'nom_du_poi', 'description', 'latitude', 'longitude', 'addr_rue',
#        'addr_cp', 'addr_commune', 'source_region', 'contact_mail',
#        'contact_phone', 'contact_website', 'sub_category_id',
#        'main_category_id', 'h3_r6', 'h3_r7', 'h3_r8', 'h3_r9',
#        'density_commune', 'density_commune_norm', 'diversity_commune',
#        'diversity_commune_norm', 'centroid_lat', 'centroid_lon',
#        'proximity_commune', 'proximity_commune_norm', 'category_weight',
#        'category_weight_norm', 'popularity_norm', 'opening_score_norm',
#        'final_score_raw', 'final_score', 'itineraire'],
#       dtype='object')
# (81606, 33)
# C:\Users\gg\AppData\Local\Temp\ipykernel_20472\3321464641.py:3: DtypeWarning: Columns (2,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
df["itineraire"].value_counts()
# Out:
# itineraire
# True     46206
# False    35400
# Name: count, dtype: int64
